# %% [markdown]
# # Neurotransmitter Explorations DeepLabCut Processing Scripts
# @written by CS 2022
#
# Query the name of each computer's GPU using 'nvidia-smi --query-gpu=gpu_name --format=csv'
#
# Install matlab in env troubleshooting: https://www.mathworks.com/matlabcentral/answers/540707-why-does-matlab-fail-to-install-with-a-std-runtime_error-what-unable-to-launch-the-matlabwind
#
# MATLAB engine for Python: https://www.mathworks.com/help/matlab/matlab_external/install-the-matlab-engine-for-python.html

# %% [markdown]
# #### Upgrading DLC

# %%
#pip install --upgrade deeplabcut

# %% [markdown]
# #### Import Dependencies & Set Paths

# %%
# Import dependencies
import os
import platform
os.environ["DLClight"]="True"
import matlab.engine
import deeplabcut

# Set path for pupil and whisker networks
if platform.system() == 'Windows':
    if os.environ['USERNAME'] == 'TheSingularity':
        project_code_repo = r'C:\Users\TheSingularity\Documents\GitHub\Neurotransmitter_Exploration'
        # Pupil
        path_config_file_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Pupil-C. Slater-2022-11-20\config.yaml'
        raw_pupil_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data'
        extract_folder_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data\DLC_extracted_data'
        # Whisker
        path_config_file_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27\config.yaml'
        raw_whisker_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data'
        extract_folder_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data\DLC_extracted_data'
    elif os.environ['COMPUTERNAME'] == 'BETADROID':
        project_code_repo = r'B:\Project_Neurotransmitter-Exploration\Neurotransmitter_Exploration'
        # Pupil
        path_config_file_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Pupil-C. Slater-2022-11-20\config.yaml'
        raw_pupil_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data'
        extract_folder_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data\DLC_extracted_data'
        # Whisker
        path_config_file_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27\config.yaml'
        raw_whisker_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data'
        extract_folder_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data\DLC_extracted_data'    
    elif os.environ['USERNAME'] == 'Convolution':
        project_code_repo = r'C:\Users\Convolution\Documents\GitHub\Neurotransmitter_Exploration'
        # Pupil
        path_config_file_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Pupil-C. Slater-2022-11-20\config.yaml'
        raw_pupil_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data'
        extract_folder_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data\DLC_extracted_data'
        # Whisker
        path_config_file_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27\config.yaml'
        raw_whisker_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data'
        extract_folder_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data\DLC_extracted_data'    
    elif os.environ['USERNAME'] == 'Fluorophore':
        project_code_repo = r'C:\Users\Fluorophore\Documents\GitHub\Neurotransmitter_Exploration'
        # Pupil
        path_config_file_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Pupil-C. Slater-2022-11-20\config.yaml'
        raw_pupil_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data'
        extract_folder_pupil = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data\DLC_extracted_data'
        # Whisker
        path_config_file_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\DeepLabCut\Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27\config.yaml'
        raw_whisker_data_path = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data'
        extract_folder_whisker = r'G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data\DLC_extracted_data'    
if platform.system() == 'Linux':
    # Shared data paths (google drive)
    # Pupil
    path_config_file_pupil = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/DeepLabCut/Behavior_Box_S1_Pupil-C. Slater-2022-11-20/config.yaml'
    raw_pupil_data_path = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
    extract_folder_pupil = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data/DLC_extracted_data'
    # Whisker
    path_config_file_whisker = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/DeepLabCut/Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27/config.yaml'
    raw_whisker_data_path = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
    extract_folder_whisker = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data/DLC_extracted_data' 

    # Betadroid
    if os.environ['LOGNAME'] == 'beta':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\beta\Neurotransmitter_Exploration'  
    # Convolution
    elif os.environ['LOGNAME'] == 'convo':
        project_code_repo = r'\\wsl.localhost\Ubuntu\home\convo\Neurotransmitter_Exploration'
    # Fluorophore
    elif os.environ['LOGNAME'] == 'fluoro':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\fluoro\Neurotransmitter_Exploration'
    # TheSingularity
    elif os.environ['LOGNAME'] == 'sing':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\sing\Neurotransmitter_Exploration'

# %% [markdown]
# ## Pupil

# %% [markdown]
# #### Setting up the pupil network for the first time (do not run everytime)

# %%
'''task='Behavior_Box_S1_Pupil' # Enter the name of your experiment Task
experimenter='C. Slater' # Enter the name of the experimenter
video=['G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Pupil Data'] # Enter the paths of your videos OR FOLDER you want to grab frames from.

path_config_file=deeplabcut.create_new_project(task,experimenter,video,copy_videos=True)'''

# %% [markdown]
# ##### Extract video frames

# %%
# %matplotlib inline

# Extract using kmeans algorithm:
deeplabcut.extract_frames(path_config_file_pupil,algo="kmeans",cluster_step=2,userfeedback=False)

# %% [markdown]
# ##### Label and check extracted video frames

# %%
deeplabcut.label_frames(path_config_file_pupil)

# %%
deeplabcut.check_labels(path_config_file_pupil)

# %% [markdown]
# ##### Create, Train, and Evaluate Network

# %%
# Create a training dataset
deeplabcut.create_training_dataset(path_config_file_pupil)

# Train network (default resnet_50)
deeplabcut.train_network(path_config_file_pupil, displayiters=10, maxiters=500000, gputouse=gpu_name)

# Evaluate network
# %matplotlib notebook
deeplabcut.evaluate_network(path_config_file_pupil,plotting=True)

# %% [markdown]
# #### Improve Network

# %% [markdown]
# ##### Extract Outliers

# %%
# Copy and paste videos from outlier_extraction_list
video=[]
deeplabcut.extract_outlier_frames(path_config_file_pupil,video,copy_videos=True,destfolder=extract_folder_pupil,automatic=True)

# %% [markdown]
# ##### Refine Labels (run on Windows native)

# %%
# Needs to be run on Windows native or launched from GUI
deeplabcut.refine_labels(path_config_file_pupil)

# %% [markdown]
# ##### Merge Datasets

# %%
deeplabcut.merge_datasets(path_config_file_pupil)

# %% [markdown]
# ##### Check Labels

# %%
# Check labels
deeplabcut.check_labels(path_config_file_pupil)

# %% [markdown]
# ##### Retrain Network

# %%
# Create a training dataset
deeplabcut.create_training_dataset(path_config_file_pupil)

# Train network (default resnet_50)
deeplabcut.train_network(path_config_file_pupil, displayiters=10, maxiters=450000)

# Evaluate network
# %matplotlib notebook
deeplabcut.evaluate_network(path_config_file_pupil,plotting=True)

# %% [markdown]
# ## Whisker

# %% [markdown]
# #### Setting up the whisker network for the first time

# %%
'''task='Behavior_Box_S1_Simple_R_Whisker' # Enter the name of your experiment Task
experimenter='C. Slater' # Enter the name of the experimenter
video=['G:\My Drive\#Projects\Project_Neurotransmitter-Exploration\Raw Whisker Data'] # Enter the paths of your videos OR FOLDER you want to grab frames from.

path_config_file=deeplabcut.create_new_project(task,experimenter,video,copy_videos=True,videotype='.mp4')'''

# %% [markdown]
# ##### Extract video frames

# %%
# %matplotlib inline

# Extract using kmeans algorithm:
deeplabcut.extract_frames(path_config_file_whisker,algo="kmeans",cluster_step=10,userfeedback=False)

# %% [markdown]
# ##### Label and check extracted video frames

# %%
# %gui wx
deeplabcut.label_frames(path_config_file_whisker)

# %%
deeplabcut.check_labels(path_config_file_whisker)

# %% [markdown]
# ##### Create, Train, and Evaluate Network

# %%
# Create a training dataset
deeplabcut.create_training_dataset(path_config_file_pupil)

# Train network (default resnet_50)
deeplabcut.train_network(path_config_file_pupil, displayiters=10, maxiters=450000)

# Evaluate network
# %matplotlib notebook
deeplabcut.evaluate_network(path_config_file_pupil,plotting=True)

# %% [markdown]
# #### Improve Network

# %% [markdown]
# ##### Extract Outliers

# %%
# Copy and paste videos from outlier_extraction_list
video=[]
deeplabcut.extract_outlier_frames(path_config_file_whisker,video,copy_videos=True,destfolder=extract_folder_whisker,outlieralgorithm='jump',epsilon=325,automatic=True)

# %% [markdown]
# ##### Refine Labels (run on Windows native)

# %%
# Needs to be run on Windows native or launched from GUI
deeplabcut.refine_labels(path_config_file_whisker)

# %% [markdown]
# ##### Merge Datasets

# %%
deeplabcut.merge_datasets(path_config_file_whisker)

# %% [markdown]
# ##### Check Labels

# %%
# Check labels
deeplabcut.check_labels(path_config_file_whisker)

# %% [markdown]
# ##### Retrain Network

# %%
# Create a training dataset
deeplabcut.create_training_dataset(path_config_file_whisker)

# Train network (default resnet_50)
deeplabcut.train_network(path_config_file_whisker, displayiters=10, maxiters=450000)

# Evaluate network
# %matplotlib notebook
deeplabcut.evaluate_network(path_config_file_whisker,plotting=True)
