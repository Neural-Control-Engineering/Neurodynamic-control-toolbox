# %% [markdown]
# ## Neurotransmitter Exploration - Daily DLC Run

# %% [markdown]
# To mount google drive in WSL:
# sudo mount -t drvfs G: /mnt/g

# %%
# Import dependencies
import os
import platform
os.environ['DLClight'] = 'True'
import matlab.engine
import deeplabcut

# Colors for messaging on screen
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# Define class to hold paths for data scraping
class data_paths:
    pass

# Set path for pupil and whisker networks
if platform.system() == 'Linux':
    # Shared data paths (google drive)
    # Pupil
    path_config_file_pupil = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/DeepLabCut/Behavior_Box_S1_Pupil-C. Slater-2022-11-20/config.yaml'
    raw_pupil_data_path = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
    extract_folder_pupil = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data/DLC_extracted_data'
    # Whisker
    path_config_file_whisker = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/DeepLabCut/Behavior_Box_S1_Simple_R_Whisker-C. Slater-2022-11-27/config.yaml'
    raw_whisker_data_path = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
    extract_folder_whisker = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data/DLC_extracted_data' 

    # Betadroid
    if os.environ['LOGNAME'] == 'beta':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\beta\Neurotransmitter_Exploration'
        data_paths.dest_behavior_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Behavior Data'
        data_paths.dest_metadata =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Experiment Metadata'
        data_paths.dest_pupil_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.dest_whisker_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.dest_photometry_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Photometry Data'
        data_paths.root_behavior_data = r'/mnt/g/Other Computers/Datatron/Raw_Data'
        data_paths.root_metadata = r'/mnt/g/Other Computers/Datatron/Raw_Data_Experimental_Details'
        data_paths.root_pupil_data = r'/mnt/g/Other Computers/Datatron/SSD_v2 Raw Pupil Data'
        data_paths.root_photometry_data = r'/mnt/g/Other Computers/Einstein/SSD_v2 Raw Photometry Data'
        data_paths.root_whisker_data = r'/mnt/g/Other Computers/Optisma/SSD_v2 Raw Whisking Data'
        data_paths.root_metadata = r'/mnt/g/Other Computers/Datatron/Raw_Data_Experimental_Details'
        data_paths.root_pupil_data = r'/mnt/g/Other Computers/Datatron/SSD_v2 Raw Pupil Data'
        data_paths.root_photometry_data = r'/mnt/g/Other Computers/Einstein/SSD_v2 Raw Photometry Data'
        data_paths.root_whisker_data = r'/mnt/g/Other Computers/Optisma/SSD_v2 Raw Whisking Data'
        data_paths.raw_pupil_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.raw_whisker_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.processed_pupil_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Pupil Data'
        data_paths.processed_whisker_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Whisker Data'
        data_paths.processed_behavior_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Behavior Data'
    # Convolution
    elif os.environ['LOGNAME'] == 'convo':
        project_code_repo = r'\\wsl.localhost\Ubuntu\home\convo\Neurotransmitter_Exploration'
        data_paths.dest_behavior_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Behavior Data'
        data_paths.dest_metadata =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Experiment Metadata'
        data_paths.dest_pupil_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.dest_whisker_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.dest_photometry_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Photometry Data'
        data_paths.root_behavior_data = r'/mnt/g/Other Computers/Datatron/Raw_Data'
        data_paths.root_metadata = r'/mnt/g/Other Computers/Datatron/Raw_Data_Experimental_Details'
        data_paths.root_pupil_data = r'/mnt/g/Other Computers/Datatron/SSD_v2 Raw Pupil Data'
        data_paths.root_photometry_data = r'/mnt/g/Other Computers/Einstein/SSD_v2 Raw Photometry Data'
        data_paths.root_whisker_data = r'/mnt/g/Other Computers/Optisma/SSD_v2 Raw Whisking Data'
        data_paths.raw_pupil_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.raw_whisker_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.processed_pupil_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Pupil Data'
        data_paths.processed_whisker_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Whisker Data'
        data_paths.processed_behavior_data = r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Processed Behavior Data'
    # Fluorophore
    elif os.environ['LOGNAME'] == 'fluoro':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\fluoro\Neurotransmitter_Exploration'
        data_paths.dest_behavior_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Behavior Data'
        data_paths.dest_metadata =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Experiment Metadata'
        data_paths.dest_pupil_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.dest_whisker_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.dest_photometry_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Photometry Data'
        data_paths.root_behavior_data = r'/mnt/g/Other Computers/Datatron/Raw_Data'
        data_paths.root_metadata = r'/mnt/g/Other Computers/Datatron/Raw_Data_Experimental_Details'
        data_paths.root_pupil_data = r'/mnt/g/Other Computers/Datatron/SSD_v2 Raw Pupil Data'
        data_paths.root_photometry_data = r'/mnt/g/Other Computers/Einstein/SSD_v2 Raw Photometry Data'
        data_paths.root_whisker_data = r'/mnt/g/Other Computers/Optisma/SSD_v2 Raw Whisking Data'
    # TheSingularirty
    elif os.environ['LOGNAME'] == 'sing':
        project_code_repo = r'\\wsl.localhost\Ubuntu-22.04\home\sing\Neurotransmitter_Exploration'
        data_paths.dest_behavior_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Behavior Data'
        data_paths.dest_metadata =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Experiment Metadata'
        data_paths.dest_pupil_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Pupil Data'
        data_paths.dest_whisker_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Whisker Data'
        data_paths.dest_photometry_data =  r'/mnt/g/My Drive/#Projects/Project_Neurotransmitter-Exploration/Raw Photometry Data'
        data_paths.root_behavior_data = r'/mnt/g/Other Computers/Datatron/Raw_Data'
        data_paths.root_metadata = r'/mnt/g/Other Computers/Datatron/Raw_Data_Experimental_Details'
        data_paths.root_pupil_data = r'/mnt/g/Other Computers/Datatron/SSD_v2 Raw Pupil Data'
        data_paths.root_photometry_data = r'/mnt/g/Other Computers/Einstein/SSD_v2 Raw Photometry Data'
        data_paths.root_whisker_data = r'/mnt/g/Other Computers/Optisma/SSD_v2 Raw Whisking Data'

#___________________________________________________________________________________________________________________
# SCRAPE NEWLY ACQUIRED DATA AND QC 
eng = matlab.engine.start_matlab()
log = eng.scrapeRawData(data_paths.root_behavior_data,data_paths.root_metadata,data_paths.root_pupil_data,
    data_paths.root_whisker_data,data_paths.root_photometry_data,data_paths.dest_behavior_data,
    data_paths.dest_metadata,data_paths.dest_pupil_data,data_paths.dest_whisker_data,data_paths.dest_photometry_data)

display(log)

#___________________________________________________________________________________________________________________
# PUPIL        
# Option to reset DLC extractions and re-extract for everything with updated network
reset_DLC = False
update_DLC = False

# Return list of videos to analyze
vids = eng.fetchPupil2Extract(raw_pupil_data_path,reset_DLC,update_DLC)

print(f"{bcolors.HEADER}List of pupil videos to extract:")
display(vids)

# Cycle through all videos not yet extracted and perform DLC extraction
for vid in vids:
    videofile_path = os.path.join(raw_pupil_data_path,vid)
    print("DLC is currently analyzing",vid)
    deeplabcut.analyze_videos(path_config_file_pupil,videofile_path, videotype='.mp4',destfolder=extract_folder_pupil)
    deeplabcut.filterpredictions(path_config_file_pupil, videofile_path, videotype='.mp4',destfolder=extract_folder_pupil)
    deeplabcut.plot_trajectories(path_config_file_pupil,videofile_path,filtered=True,destfolder=extract_folder_pupil,displayedbodyparts='all')
    log = eng.logPupilExtraction(raw_pupil_data_path,vid)
    print(f"{bcolors.OKGREEN}" + log)

#___________________________________________________________________________________________________________________
#WHISKER
# Option to reset DLC extractions and re-extract for everything with updated network
reset_DLC = False
update_DLC = False

# Launch matlab function to return list of videos to analyze
eng = matlab.engine.start_matlab()
vids = eng.fetchWhisker2Extract(raw_whisker_data_path,reset_DLC,update_DLC)
 
print(f"{bcolors.HEADER}List of whisker videos to extract:")
display(vids)

# Cycle through all videos not yet extracted and perform DLC extraction
for vid in vids:
    videofile_path = os.path.join(raw_whisker_data_path,vid)
    print("DLC is currently analyzing",vid)
    deeplabcut.analyze_videos(path_config_file_whisker,videofile_path,videotype='.mp4',destfolder=extract_folder_whisker)
    deeplabcut.filterpredictions(path_config_file_whisker,videofile_path,videotype='.mp4',destfolder=extract_folder_whisker)
    deeplabcut.plot_trajectories(path_config_file_whisker,videofile_path,filtered=True,destfolder=extract_folder_whisker,displayedbodyparts='all')
    log = eng.logWhiskerExtraction(raw_whisker_data_path,vid)
    print(f"{bcolors.OKGREEN}" + log)


log = eng.updateDLCDataNTEXAuto()
display(log)

eng.quit()
# Out:
# 2023-04-27 22:28:17.494845: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 22:28:18.270225: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-04-27 22:28:19.057832: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/beta/miniconda3/envs/DEEPLABCUT/lib/
# ...
